# %%
import pandas as pd

# Read the data from the CSV file
data = pd.read_csv('New_Data/train.csv')

# Display the first few rows of the data
print(data.head())
# Out:
#                                                 text  label
# 0  Effects of agriculture crop residue burning on...      1
# 1  Health impact and monetary cost of exposure to...      1
# 2  Reducing mortality risk by targeting speciﬁc a...      1
# 3  Atmospheric Pollution Research 13 (2022) 10141...      1
# 4  Original article\nShort-term associations of P...      1

# %%
data
# Out:
#                                                  text  label
# 0   Effects of agriculture crop residue burning on...      1
# 1   Health impact and monetary cost of exposure to...      1
# 2   Reducing mortality risk by targeting speciﬁc a...      1
# 3   Atmospheric Pollution Research 13 (2022) 10141...      1
# 4   Original article\nShort-term associations of P...      1
# 5   1.  Introduction\nIn Africa, fine particulate ...      1
# 6        \nLETTER • OPEN ACCESS\nGlobal burden of ...      1
# 7   ORIGINAL PAPER\nStochastic Environmental Resea...      1
# 8   Vol.:(0123456789)\n1 3\nExposure and Health (2...      1
# 9   RESEARCH\nOpen Access\nAmbient particulate mat...      1
# 10  Estimating emissions from open burning of muni...      0
# 11  International  Journal  of\nEnvironmental Rese...      0

# %%
medical_data = pd.read_csv('raw_combined_2.csv')
medical_data
# Out:
#                                                    text  label
# 0      \n1\nPolyethylene Glycol-Mediated Directional...      1
# 1      \n \n \n \n \nTitle \nRisk factors for arbovi...      1
# 2      \n1 \nContinuous non-invasive hemodynamic mon...      1
# 3     TITLE PAGE \nTitle \niSPAN:  Improved predicti...      1
# 4     1 \n \nQuantifying the Risk of General Health ...      1
# ...                                                 ...    ...
# 1993  1 \n \nEconomic thermodynamics \n \nS.A. Rashk...      0
# 1994   \n \n \nBRASIL \nINFORME PAÍS \nJUAN B. GONZÁ...      0
# 1995  A QUANTUM ALGORITHM FOR LINEAR PDES ARISING IN...      0
# 1996  arXiv:0912.1617v1  [q-fin.ST]  8 Dec 2009\nArt...      0
# 1997  Interpreting Economic Complexity\nPenny Mealy∗...      0
#
# [1998 rows x 2 columns]

# %%
# count the unique labels
labels = medical_data['label']
print(labels.value_counts())
# Out:
# label
# 0    1108
# 1     890
# Name: count, dtype: int64
